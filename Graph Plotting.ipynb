# %%
x = [5.8 ,2.1, 1.3, 3, 1.8]
y = [10.17, 3.141, 3.56, 4.011, 4.46]

import matplotlib.pyplot as plt

plt.plot([5.8, 1.3, 2.1 ,1.8 ,3] , [10.17 ,3.141 ,3.56 ,4.011 ,3.29] , color='red', marker='o', label = "x")
plt.plot([5.8, 1.3, 2.1, 1.8, 3] , [10.17 ,3.141 ,3.56 ,4.011 ,2.39] , color='blue', marker="o", label = "y")
plt.plot([5.8, 1.3, 2.1 ,1.8 ,3] , [10.17 ,3.141 ,3.56 ,4.011 ,1.40] , color='yellow', marker='o', label = "y1")
plt.legend(loc = "upper left")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
#fig1 = plt.gcf()
plt.show()
#plt.draw()
#fig1.savefig("test.png", dpi = 100)
