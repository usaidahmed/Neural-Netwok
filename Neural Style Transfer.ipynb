# %%
from keras.preprocessing.image import load_img, img_to_array
target_image_path = 'pic.jpeg'
style_reference_image_path = 'OIP2.jfif'
width, height = load_img(target_image_path).size
img_height = 400
img_width = int(width * img_height / height)
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
from keras.applications import vgg19
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %%
def deprocess_image(x):
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
from keras import backend as K
target_image = K.constant(preprocess_image(target_image_path))
style_reference_image = K.constant(preprocess_image(style_reference_image_path))
combination_image = K.placeholder((1, img_height, img_width, 3))
input_tensor = K.concatenate([target_image,style_reference_image, combination_image], axis=0)
model = vgg19.VGG19(input_tensor=input_tensor,weights='imagenet',include_top=False)
print('Model loaded.')
# Out:
# Model loaded.

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# %%
def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_height * img_width
    return K.sum(K.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

# %%
def total_variation_loss(x):
    a = K.square(
    x[:, :img_height - 1, :img_width - 1, :] -
    x[:, 1:, :img_width - 1, :])
    b = K.square(
    x[:, :img_height - 1, :img_width - 1, :] -
    x[:, :img_height - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
content_layer = 'block5_conv2'
style_layers = ['block1_conv1','block2_conv1','block3_conv1','block4_conv1','block5_conv1']
total_variation_weight = 1e-4
style_weight = 1.
content_weight = 0.50

# %%
loss = K.variable(0.)
layer_features = outputs_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss = loss + content_weight * content_loss(target_image_features,combination_features)

# %%
for layer_name in style_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss = loss + (style_weight / len(style_layers)) * sl

# %%
loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %%
grads = K.gradients(loss, combination_image)[0]
fetch_loss_and_grads = K.function([combination_image], [loss, grads])

# %%
class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        x = x.reshape((1, img_height, img_width, 3))
        outs = fetch_loss_and_grads([x])
        loss_value = outs[0]
        grad_values = outs[1].flatten().astype('float64')
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values    
    
evaluator = Evaluator()

# %%
from scipy.optimize import fmin_l_bfgs_b
import imageio
import time
result_prefix = 'my_result'
iterations = 100
x = preprocess_image(target_image_path)
x = x.flatten()

# %%
for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x, fprime=evaluator.grads,maxfun=50)
    print('Current loss value:', min_val)
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_image(img)
    fname = result_prefix + '_at_iteration_%d.png' % i
    imageio.imwrite(fname, img)
    print('Image saved as', fname)
    end_time = time.time()
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 2514685200.0
# Image saved as my_result_at_iteration_0.png
# Iteration 0 completed in 20s
# Start of iteration 1
# Current loss value: 1213164300.0
# Image saved as my_result_at_iteration_1.png
# Iteration 1 completed in 14s
# Start of iteration 2
# Current loss value: 896076900.0
# Image saved as my_result_at_iteration_2.png
# Iteration 2 completed in 14s
# Start of iteration 3
# Current loss value: 740267460.0
# Image saved as my_result_at_iteration_3.png
# Iteration 3 completed in 14s
# Start of iteration 4
# Current loss value: 649760500.0
# Image saved as my_result_at_iteration_4.png
# Iteration 4 completed in 14s
# Start of iteration 5
# Current loss value: 592431000.0
# Image saved as my_result_at_iteration_5.png
# Iteration 5 completed in 14s
# Start of iteration 6
# Current loss value: 549639700.0
# Image saved as my_result_at_iteration_6.png
# Iteration 6 completed in 14s
# Start of iteration 7
# Current loss value: 517848640.0
# Image saved as my_result_at_iteration_7.png
# Iteration 7 completed in 14s
# Start of iteration 8
# Current loss value: 493923900.0
# Image saved as my_result_at_iteration_8.png
# Iteration 8 completed in 14s
# Start of iteration 9
# Current loss value: 474170270.0
# Image saved as my_result_at_iteration_9.png
# Iteration 9 completed in 14s
# Start of iteration 10
# Current loss value: 458464200.0
# Image saved as my_result_at_iteration_10.png
# Iteration 10 completed in 14s
# Start of iteration 11
# Current loss value: 445473900.0
# Image saved as my_result_at_iteration_11.png
# Iteration 11 completed in 14s
# Start of iteration 12
# Current loss value: 433420860.0
# Image saved as my_result_at_iteration_12.png
# Iteration 12 completed in 14s
# Start of iteration 13
# Current loss value: 422629060.0
# Image saved as my_result_at_iteration_13.png
# Iteration 13 completed in 14s
# Start of iteration 14
# Current loss value: 413470500.0
# Image saved as my_result_at_iteration_14.png
# Iteration 14 completed in 14s
# Start of iteration 15
# Current loss value: 405652220.0
# Image saved as my_result_at_iteration_15.png
# Iteration 15 completed in 14s
# Start of iteration 16
# Current loss value: 398560580.0
# Image saved as my_result_at_iteration_16.png
# Iteration 16 completed in 14s
# Start of iteration 17
# Current loss value: 392225570.0
# Image saved as my_result_at_iteration_17.png
# Iteration 17 completed in 14s
# Start of iteration 18
# Current loss value: 386042560.0
# Image saved as my_result_at_iteration_18.png
# Iteration 18 completed in 14s
# Start of iteration 19
# Current loss value: 380958880.0
# Image saved as my_result_at_iteration_19.png
# Iteration 19 completed in 14s
# Start of iteration 20
# Current loss value: 376218240.0
# Image saved as my_result_at_iteration_20.png
# Iteration 20 completed in 14s
# Start of iteration 21
# Current loss value: 371900030.0
# Image saved as my_result_at_iteration_21.png
# Iteration 21 completed in 14s
# Start of iteration 22
# Current loss value: 367615460.0
# Image saved as my_result_at_iteration_22.png
# Iteration 22 completed in 14s
# Start of iteration 23
# Current loss value: 363975170.0
# Image saved as my_result_at_iteration_23.png
# Iteration 23 completed in 14s
# Start of iteration 24
# Current loss value: 360536930.0
# Image saved as my_result_at_iteration_24.png
# Iteration 24 completed in 14s
# Start of iteration 25
# Current loss value: 357464130.0
# Image saved as my_result_at_iteration_25.png
# Iteration 25 completed in 14s
# Start of iteration 26
# Current loss value: 354444350.0
# Image saved as my_result_at_iteration_26.png
# Iteration 26 completed in 14s
# Start of iteration 27
# Current loss value: 351485150.0
# Image saved as my_result_at_iteration_27.png
# Iteration 27 completed in 14s
# Start of iteration 28
# Current loss value: 348593300.0
# Image saved as my_result_at_iteration_28.png
# Iteration 28 completed in 14s
# Start of iteration 29
# Current loss value: 346012860.0
# Image saved as my_result_at_iteration_29.png
# Iteration 29 completed in 14s
# Start of iteration 30
# Current loss value: 343775140.0
# Image saved as my_result_at_iteration_30.png
# Iteration 30 completed in 14s
# Start of iteration 31
# Current loss value: 341586880.0
# Image saved as my_result_at_iteration_31.png
# Iteration 31 completed in 14s
# Start of iteration 32
# Current loss value: 339482660.0
# Image saved as my_result_at_iteration_32.png
# Iteration 32 completed in 14s
# Start of iteration 33
# Current loss value: 337577570.0
# Image saved as my_result_at_iteration_33.png
# Iteration 33 completed in 14s
# Start of iteration 34
# Current loss value: 335680060.0
# Image saved as my_result_at_iteration_34.png
# Iteration 34 completed in 14s
# Start of iteration 35
# Current loss value: 333832030.0
# Image saved as my_result_at_iteration_35.png
# Iteration 35 completed in 14s
# Start of iteration 36
# Current loss value: 332259230.0
# Image saved as my_result_at_iteration_36.png
# Iteration 36 completed in 14s
# Start of iteration 37
# Current loss value: 330610500.0
# Image saved as my_result_at_iteration_37.png
# Iteration 37 completed in 14s
# Start of iteration 38
# Current loss value: 328875550.0
# Image saved as my_result_at_iteration_38.png
# Iteration 38 completed in 14s
# Start of iteration 39
# Current loss value: 327485600.0
# Image saved as my_result_at_iteration_39.png
# Iteration 39 completed in 14s
# Start of iteration 40
# Current loss value: 326195780.0
# Image saved as my_result_at_iteration_40.png
# Iteration 40 completed in 14s
# Start of iteration 41
# Current loss value: 325051550.0
# Image saved as my_result_at_iteration_41.png
# Iteration 41 completed in 14s
# Start of iteration 42
# Current loss value: 323771360.0
# Image saved as my_result_at_iteration_42.png
# Iteration 42 completed in 14s
# Start of iteration 43
# Current loss value: 322554600.0
# Image saved as my_result_at_iteration_43.png
# Iteration 43 completed in 14s
# Start of iteration 44
# Current loss value: 321378430.0
# Image saved as my_result_at_iteration_44.png
# Iteration 44 completed in 14s
# Start of iteration 45
# Current loss value: 320135940.0
# Image saved as my_result_at_iteration_45.png
# Iteration 45 completed in 14s
# Start of iteration 46
# Current loss value: 319105800.0
# Image saved as my_result_at_iteration_46.png
# Iteration 46 completed in 14s
# Start of iteration 47
# Current loss value: 318191360.0
# Image saved as my_result_at_iteration_47.png
# Iteration 47 completed in 14s
# Start of iteration 48
# Current loss value: 317149150.0
# Image saved as my_result_at_iteration_48.png
# Iteration 48 completed in 14s
# Start of iteration 49
# Current loss value: 316159260.0
# Image saved as my_result_at_iteration_49.png
# Iteration 49 completed in 14s
# Start of iteration 50
# Current loss value: 315245660.0
# Image saved as my_result_at_iteration_50.png
# Iteration 50 completed in 14s
# Start of iteration 51
# Current loss value: 314349280.0
# Image saved as my_result_at_iteration_51.png
# Iteration 51 completed in 14s
# Start of iteration 52
# Current loss value: 313470500.0
# Image saved as my_result_at_iteration_52.png
# Iteration 52 completed in 14s
# Start of iteration 53
# Current loss value: 312645120.0
# Image saved as my_result_at_iteration_53.png
# Iteration 53 completed in 14s
# Start of iteration 54
# Current loss value: 311808640.0
# Image saved as my_result_at_iteration_54.png
# Iteration 54 completed in 14s
# Start of iteration 55
# Current loss value: 310995700.0
# Image saved as my_result_at_iteration_55.png
# Iteration 55 completed in 14s
# Start of iteration 56
# Current loss value: 310225570.0
# Image saved as my_result_at_iteration_56.png
# Iteration 56 completed in 14s
# Start of iteration 57
# Current loss value: 309492300.0
# Image saved as my_result_at_iteration_57.png
# Iteration 57 completed in 14s
# Start of iteration 58
# Current loss value: 308778850.0
# Image saved as my_result_at_iteration_58.png
# Iteration 58 completed in 14s
# Start of iteration 59
# Current loss value: 308039520.0
# Image saved as my_result_at_iteration_59.png
# Iteration 59 completed in 14s
# Start of iteration 60
# Current loss value: 307260320.0
# Image saved as my_result_at_iteration_60.png
# Iteration 60 completed in 14s
# Start of iteration 61
# Current loss value: 306594370.0
# Image saved as my_result_at_iteration_61.png
# Iteration 61 completed in 14s
# Start of iteration 62
# Current loss value: 305951200.0
# Image saved as my_result_at_iteration_62.png
# Iteration 62 completed in 14s
# Start of iteration 63
# Current loss value: 305351040.0
# Image saved as my_result_at_iteration_63.png
# Iteration 63 completed in 14s
# Start of iteration 64
# Current loss value: 304750140.0
# Image saved as my_result_at_iteration_64.png
# Iteration 64 completed in 14s
# Start of iteration 65
# Current loss value: 304202800.0
# Image saved as my_result_at_iteration_65.png
# Iteration 65 completed in 14s
# Start of iteration 66
# Current loss value: 303656320.0
# Image saved as my_result_at_iteration_66.png
# Iteration 66 completed in 14s
# Start of iteration 67
# Current loss value: 303094300.0
# Image saved as my_result_at_iteration_67.png
# Iteration 67 completed in 14s
# Start of iteration 68
# Current loss value: 302543580.0
# Image saved as my_result_at_iteration_68.png
# Iteration 68 completed in 14s
# Start of iteration 69
# Current loss value: 302053380.0
# Image saved as my_result_at_iteration_69.png
# Iteration 69 completed in 14s
# Start of iteration 70
# Current loss value: 301552930.0
# Image saved as my_result_at_iteration_70.png
# Iteration 70 completed in 14s
# Start of iteration 71
# Current loss value: 301079870.0
# Image saved as my_result_at_iteration_71.png
# Iteration 71 completed in 14s
# Start of iteration 72
# Current loss value: 300618660.0
# Image saved as my_result_at_iteration_72.png
# Iteration 72 completed in 14s
# Start of iteration 73
# Current loss value: 300178980.0
# Image saved as my_result_at_iteration_73.png
# Iteration 73 completed in 14s
# Start of iteration 74
# Current loss value: 299737760.0
# Image saved as my_result_at_iteration_74.png
# Iteration 74 completed in 14s
# Start of iteration 75
# Current loss value: 299326530.0
# Image saved as my_result_at_iteration_75.png
# Iteration 75 completed in 14s
# Start of iteration 76
# Current loss value: 298918530.0
# Image saved as my_result_at_iteration_76.png
# Iteration 76 completed in 14s
# Start of iteration 77
# Current loss value: 298526340.0
# Image saved as my_result_at_iteration_77.png
# Iteration 77 completed in 14s
# Start of iteration 78
# Current loss value: 298141060.0
# Image saved as my_result_at_iteration_78.png
# Iteration 78 completed in 14s
# Start of iteration 79
# Current loss value: 297774600.0
# Image saved as my_result_at_iteration_79.png
# Iteration 79 completed in 14s
# Start of iteration 80
# Current loss value: 297400260.0
# Image saved as my_result_at_iteration_80.png
# Iteration 80 completed in 14s
# Start of iteration 81
# Current loss value: 297046370.0
# Image saved as my_result_at_iteration_81.png
# Iteration 81 completed in 14s
# Start of iteration 82
# Current loss value: 296679230.0
# Image saved as my_result_at_iteration_82.png
# Iteration 82 completed in 14s
# Start of iteration 83
# Current loss value: 296335870.0
# Image saved as my_result_at_iteration_83.png
# Iteration 83 completed in 14s
# Start of iteration 84
# Current loss value: 295984220.0
# Image saved as my_result_at_iteration_84.png
# Iteration 84 completed in 14s
# Start of iteration 85
# Current loss value: 295624260.0
# Image saved as my_result_at_iteration_85.png
# Iteration 85 completed in 14s
# Start of iteration 86
# Current loss value: 295260600.0
# Image saved as my_result_at_iteration_86.png
# Iteration 86 completed in 14s
# Start of iteration 87
# Current loss value: 294901980.0
# Image saved as my_result_at_iteration_87.png
# Iteration 87 completed in 14s
# Start of iteration 88
# Current loss value: 294532770.0
# Image saved as my_result_at_iteration_88.png
# Iteration 88 completed in 14s
# Start of iteration 89
# Current loss value: 294195970.0
# Image saved as my_result_at_iteration_89.png
# Iteration 89 completed in 14s
# Start of iteration 90
# Current loss value: 293869900.0
# Image saved as my_result_at_iteration_90.png
# Iteration 90 completed in 14s
# Start of iteration 91
# Current loss value: 293551460.0
# Image saved as my_result_at_iteration_91.png
# Iteration 91 completed in 14s
# Start of iteration 92
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-fa5782a75b4f> in <module>
#       2     print('Start of iteration', i)
#       3     start_time = time.time()
# ----> 4     x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x, fprime=evaluator.grads,maxfun=50)
#       5     print('Current loss value:', min_val)
#       6     img = x.copy().reshape((img_height, img_width, 3))
#
# ~\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     196             'maxls': maxls}
#     197
# --> 198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     199                            **opts)
#     200     d = {'grad': res['jac'],
#
# ~\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# ~\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     293     else:
#     294         def func_and_grad(x):
# --> 295             f = fun(x, *args)
#     296             g = jac(x, *args)
#     297             return f, g
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# <ipython-input-14-1139b8da73dc> in loss(self, x)
#       8         assert self.loss_value is None
#       9         x = x.reshape((1, img_height, img_width, 3))
# ---> 10         outs = fetch_loss_and_grads([x])
#      11         loss_value = outs[0]
#      12         grad_values = outs[1].flatten().astype('float64')
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3798     return nest.pack_sequence_as(
#    3799         self._outputs_structure,
# -> 3800         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3801         expand_composites=True)
#    3802
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in <listcomp>(.0)
#    3798     return nest.pack_sequence_as(
#    3799         self._outputs_structure,
# -> 3800         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3801         expand_composites=True)
#    3802
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#     925     # pylint: disable=protected-access
#     926     try:
# --> 927       return self._numpy_internal()
#     928     except core._NotOkStatusException as e:
#     929       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:
